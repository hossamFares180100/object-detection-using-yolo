# %%
#https://universe.roboflow.com/inteligencia-artificial-proyecto-final-0qzli/piedra-papel-o-tijeras/dataset/6#
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AE4x6F2UzA8PofP1XkmV")
project = rf.workspace("inteligencia-artificial-proyecto-final-0qzli").project("piedra-papel-o-tijeras")
version = project.version(6)
dataset = version.download("yolov9")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.2/107.7 GB disk)

# %%
# Build a YOLOv9c model from scratch and train it on the COCO8 example dataset for 100 epochs
# !yolo train model=yolov9c.yaml data=RPS/data.yaml epochs=2 imgsz=640 batch=4
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from IPython.display import Image, display

# %%
display(Image(filename=f"/content/runs/detect/train/results.png", width=1000))

# %%
display(Image(filename=f"/content/runs/detect/train/confusion_matrix.png", width=1000))

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt imgsz=640 conf=0.5 \
source=/content/RPS/test/images
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv9c summary (fused): 384 layers, 25321561 parameters, 0 gradients, 102.3 GFLOPs
#
# image 1/50 /content/RPS/test/images/Imagen-de-WhatsApp-2023-11-22-a-las-22-56-12_057bf138_jpg.rf.2494a8f698e66ecc1aad8691ca41ee90.jpg: 640x640 (no detections), 2515.7ms
# image 2/50 /content/RPS/test/images/Imagen-de-WhatsApp-2023-11-23-a-las-12-09-38_5ce93301_jpg.rf.37db3622b5f0bfbe8529781690b45d3a.jpg: 640x640 (no detections), 2642.6ms
# image 3/50 /content/RPS/test/images/Imagen-de-WhatsApp-2023-11-23-a-las-12-09-40_0afe4a06_jpg.rf.31db1685fe1979a0c4547a622ee0424e.jpg: 640x640 (no detections), 2385.5ms
# image 4/50 /content/RPS/test/images/Imagen-de-WhatsApp-2023-11-23-a-las-12-46-17_6ff77ce7_jpg.rf.8488d05a7b997a05addc3f37f9e6a0e1.jpg: 640x640 (no detections), 2565.6ms
# ...

# %%
# Display inference on ALL test images
import glob
from IPython.display import Image, display
i = 0
for imageName in glob.glob("runs/detect/predict/*.jpg"): #assuming JPG
    if i %25 ==0 :
        print("\n")
        display(Image(filename=imageName))
    i = i +1
